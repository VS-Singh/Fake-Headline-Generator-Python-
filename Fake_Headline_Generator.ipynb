# %%
# import random module
import random

# %%
# create subjects
subjects = [
    "Rohit Sharma",
    "Virat Kohli",
    "Axar Patel",
    "A cat",
    "Monkey",
    "Modi",
    "Auto Rikshaw",
    "Laptop",
    "Banana",
    "Mount Everest",
    "Harry Potter",
    "Train Station",
    "Pizza",
    "Football",
    "Sunflower",
    "Robot",
    "River Ganga",
    "Spaceship",
    "Dog",
    "Cricket Bat",
    "Rainbow",
    "Coffee Mug",
    "Elephant",
    "Metro Rail",
    "Ice Cream",
]

# %%
actions=[
    "launches",
    "cancels",
    "eats",
    "orders",
    "runs",
    "jumps",
    "drives",
    "sings",
    "writes",
    "reads",
    "builds",
    "destroys",
    "creates",
    "paints",
    "plays",
    "teaches",
    "learns",
    "buys",
    "sells",
    "throws",
    "catches",
    "fixes",
    "breaks",
    "opens",
    "closes",
    "laughs",
]

# %%
place_of_thing =[
    "Red Fort",
    "in Mumbai",
    "plote of samosa",
    "Taj Mahal",
    "India Gate",
    "Marine Drive",
    "Cubbon Park",
    "Howrah Bridge",
    "Charminar",
    "Gateway of India",
    "Himalayas",
    "Juhu Beach",
    "Lotus Temple",
    "Mysore Palace",
    "Qutub Minar",
    "Golden Temple",
    "Victoria Memorial",
    "Chowpatty Beach",
    "Bangalore Palace",
    "Ajanta C"
]

# %%
# Start headline generation loop
while True:
    subject = random.choice(subjects)
    action = random.choice(actions)
    place = random.choice(places)

    headline = f"Breaking News: {subject} {action} {place}"
    print("\n" + headline)

    user_input = input("Do you want another Headline? (yes/no): ").strip().lower()
    if user_input == "no":
        break

# print goodbye message
print("\nThank you for using the headline generator. Have a fun day!")
# Out:
# Breaking News: Monkey cancels on Mars
# Do you want another Headline? (yes/no):  yes
# Breaking News: Virat Kohli cancels in Mumbai
# Do you want another Headline? (yes/no):  yes
# Breaking News: Virat Kohli builds on Mars
# Do you want another Headline? (yes/no):  yes
# Breaking News: Rohit Sharma builds on Mars
# Do you want another Headline? (yes/no):  yes
# Breaking News: Pizza builds at Juhu Beach
# Do you want another Headline? (yes/no):  no
# Thank you for using the headline generator. Have a fun day!
